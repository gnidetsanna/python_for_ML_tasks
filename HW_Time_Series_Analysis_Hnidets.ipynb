# %% [markdown]
# <a href="https://colab.research.google.com/github/gnidetsanna/python_for_ML_tasks/blob/main/HW_Time_Series_Analysis_Hnidets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# У цьому ДЗ ми попрактикуємось моделювати часові ряди на даних з [Store Item Demand Forecasting Challenge](https://www.kaggle.com/competitions/demand-forecasting-kernels-only/overview). Ми будемо працювати лише з тренувальними даними цього змагання і задача у нас буде дещо змінена. Фокус буде на пошуці найкращої моделі, експериментах і використанні функціоналу `darts`.
#
# Якщо якісно попрацювати в цьому завданні - це буде чудовий приклад проєкту для вашого портфоліо: "спрогнозував(-ла) поденні продажі на 1 міс для 50 товарів в 10 магазинах" звучить вражаюче! Але ми в рамках ДЗ для оптимізації часу сконцентруємось на моделюванні продажів одного товару в одному магазині.
#
# **Задача**
#
# Вам надано дані про продажі товарів у магазинах за 5 років. Хочемо навчитись передачати продажі в наступному місяці поденно кожного з 50 товарів у кожному з 10 магазинів. Відповідно будемо проводити експерименти, аби знайти найкращу модель для цього.
#
# На відміну від змагання, ми будемо використовувати метрику МАРЕ (Mean Absolute Percentage Error) замість SMAPE (Symmetric Mean Absolute Percentage Error). Проте, ви також можете розрахувати SMAPE і подати свої результати через late submission на Kaggle.

# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# !pip install darts --quiet
from darts import TimeSeries
# Out:
# Mounted at /content/drive
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 2.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 165.8/165.8 kB 4.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 934.2/934.2 kB 32.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 47.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 815.2/815.2 kB 39.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 314.7/314.7 kB 19.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 8.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 271.4/271.4 kB 16.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 16.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 890.6/890.6 kB 37.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.4/41.4 kB 2.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 3.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.3/135.3 kB 9.0 MB/s eta 0:00:00
#   Building wheel for pyod (setup.py) ... done

# %% [markdown]
# 1. Завантажуємо дані в Pandas.
#
#   1. Завантажте дані з файлу `train.csv.zip` за допомогою бібліотеки Pandas.
#   2. Перетворіть колонку `date` на формат `datetime`.
#   3. Встановіть колонку `date` як індекс для датафрейму.
#   4. Виведіть перші 10 рядків отриманого датафрейму та інформацію про датафрейм.

# %%
train_df = pd.read_csv('/content/drive/MyDrive/train.csv (1).zip')
train_df['date'] = pd.to_datetime(train_df['date'])
train_df.set_index('date',inplace=True)
train_df.head(10)
# Out:
#             store  item  sales
# date
# 2013-01-01      1     1     13
# 2013-01-02      1     1     11
# 2013-01-03      1     1     14
# 2013-01-04      1     1     13
# 2013-01-05      1     1     10
# 2013-01-06      1     1     12
# 2013-01-07      1     1     10
# 2013-01-08      1     1      9
# 2013-01-09      1     1     12
# 2013-01-10      1     1      9

# %%
train_df.describe()
# Out:
#                store           item          sales
# count  913000.000000  913000.000000  913000.000000
# mean        5.500000      25.500000      52.250287
# std         2.872283      14.430878      28.801144
# min         1.000000       1.000000       0.000000
# 25%         3.000000      13.000000      30.000000
# 50%         5.500000      25.500000      47.000000
# 75%         8.000000      38.000000      70.000000
# max        10.000000      50.000000     231.000000

# %% [markdown]
#   2. Давайте трошки зрозуміємо дані. У нас 10 магазинів і 50 айтемів в кожному. Хочемо зрозуміти, чи відрізняється динаміка по кожному айтему в магазинах. Як би ви це візуалізували? Побудуйте 3 графіка, які вам допоможуть. Можна використати будь-який інструмент: matplotlib, seaborn, plotly.
#
#   Напишіть висновок з побудованих вами візуалізацій.
#
#     **Підказка**: я б спробувала вивести середнє значення і довірчий інтервал (який включає весь діапазон значень з різних магазинів) для динаміки кожного айтема, або принаймні для декількох айтемів, аби зрозуміти тенденцію.

# %%
import seaborn as sns

sns.set_theme(style="whitegrid")

for i in range(10):

    test_df = train_df[train_df["store"] == i + 1]
    test_df = test_df.reset_index()
    test_df = test_df.groupby("item", as_index=False)["sales"].sum()
    sorted_df = test_df.sort_values(by="sales", ascending=True)

    sorted_df["item"] = sorted_df["item"].astype("category").cat.reorder_categories(sorted_df["item"], ordered=True)

    plt.figure(figsize=(10,26))

    sns.barplot(x="sales", y="item", legend=False, data=sorted_df)
    plt.ylabel("Sales amount")
    plt.xlabel("")
    plt.title(f"Store {i + 1}", fontsize=14, weight='bold')

    plt.show()

# %%
sns.set_theme(style="whitegrid")

plt.figure(figsize=(10,15))

sns.boxplot(x="store", y="sales", legend=False, data=train_df)
plt.ylabel("Sales amount")
plt.xlabel("")
plt.title(f"Store {i + 1}", fontsize=14, weight='bold')

plt.show()

# %% [markdown]
# 3. **Для початку проаналізуємо лише один ряд, а далі зможемо зациклити тренування моделей.**
#
#   Виберіть підмножину даних, що відповідає продажам товару з `item == 1` у магазині з `store == 1`.
#
#   Зробіть декомпозицію цього рядку за адитивною моделлю на тренд, сезонність і залишки з бібліотекою `statsmodels`.
#
#   Зробіть висновки з отриманих візуалізацій. Чи щось би могло вам допомогти ліпше зрозуміти ці візуалізації? (з точки зору обробки даних)

# %%
store_one = train_df["store"] == 1
item_one = train_df["item"] == 1

filtered_df = train_df.loc[store_one & item_one]

filtered_df["sales"].plot()
# Out:
# <Axes: xlabel='date'>

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
decomposition_plot_multi = seasonal_decompose(filtered_df['sales'],
                                              model='multiplicative')
decomposition_plot_multi.plot()
plt.show()

# %%
decomposition_plot_multi_short = seasonal_decompose(filtered_df[-90:]['sales'],
                                              model='multiplicative')
decomposition_plot_multi_short.plot()
plt.show()

# %% [markdown]
# 4. Зі створеної підможени даних в попередньому пункті створіть обʼєкт класу `TimeSeries` в `darts` лише для колонки `sales`.

# %%
series = TimeSeries.from_dataframe(filtered_df, value_cols='sales')

series
# Out:
# <TimeSeries (DataArray) (date: 1826, component: 1, sample: 1)> Size: 15kB
# array([[[13.]],
#
#        [[11.]],
#
#        [[14.]],
#
#        ...,
#
#        [[15.]],
#
#        [[27.]],
#
#        [[23.]]])
# Coordinates:
#   * date       (date) datetime64[ns] 15kB 2013-01-01 2013-01-02 ... 2017-12-31
#   * component  (component) object 8B 'sales'
# Dimensions without coordinates: sample
# Attributes:
#     static_covariates:  None
#     hierarchy:          None

# %% [markdown]
# 5. Використовуючи метод `series.split_before` розбийте дані на тренування і валідацію так, аби валідація починалась з `2017-10-01` включно.
#
#   Візуалізуйте на одному графіку тренувальну і валідаційну частину як було показано в лекції.

# %%
train,val = series.split_before(pd.Timestamp("2017-10-01"))

val
# Out:
# <TimeSeries (DataArray) (date: 92, component: 1, sample: 1)> Size: 736B
# array([[[21.]],
#
#        [[12.]],
#
#        [[18.]],
#
#        [[15.]],
#
#        [[20.]],
#
#        [[19.]],
#
#        [[22.]],
#
#        [[19.]],
#
#        [[ 9.]],
#
#        [[23.]],
#
# ...
#
#        [[ 6.]],
#
#        [[18.]],
#
#        [[19.]],
#
#        [[13.]],
#
#        [[16.]],
#
#        [[14.]],
#
#        [[19.]],
#
#        [[15.]],
#
#        [[27.]],
#
#        [[23.]]])
# Coordinates:
#   * date       (date) datetime64[ns] 736B 2017-10-01 2017-10-02 ... 2017-12-31
#   * component  (component) object 8B 'sales'
# Dimensions without coordinates: sample
# Attributes:
#     static_covariates:  None
#     hierarchy:          None

# %% [markdown]
# 6. Побудуйте часткову автокореляційну фукнцію для цього нашого ряду в `series`. Напишіть висновки - які лаги є важливими для прогнозування?

# %%
from statsmodels.graphics.tsaplots import plot_pacf
plt.figure(figsize=(10, 6))
plot_pacf(filtered_df["sales"], lags=60, method='ywm', )
plt.title('Partial Autocorrelation Function (PACF)')
plt.show()

# %% [markdown]
# 7. Виявіть сезональність тренувального ряду використовуючи фукнкцію `check_seasonality` з `darts`.

# %%
from darts.utils.statistics import plot_acf, check_seasonality
from darts.models import ExponentialSmoothing, AutoARIMA, Theta

for m in range(2, 25):
    is_seasonal, period = check_seasonality(train, m=m, alpha=0.05)
    if is_seasonal:
        print("There is seasonality of order {}.".format(period))
# Out:
# /usr/local/lib/python3.10/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.
#
#   warnings.warn(msg, FutureWarning)
# There is seasonality of order 7.
# There is seasonality of order 14.
# There is seasonality of order 21.

# %% [markdown]
# 8. Побудуйте наївну модель NaiveSeasonal + NaieDrift для прогнозування даних. Кількість кроків для прогнозування визначіть зі свого аналізу в попередніх пунктах. Візуалізайте передбачення проти справжніх даних так, аби було видно якість передбачень. Зробіть висновок про модель. Вона точна?
#
#   Якщо у вас є ідеї, як поліпшити якість передбачення саме наївними моделями - реалізуйте їх в цьому пункті :)

# %%
from darts.models import NaiveDrift, NaiveSeasonal

# %%
seasonal_model = NaiveSeasonal(K=14)
seasonal_model.fit(train)
seasonal_forecast = seasonal_model.predict(len(val))

train[-60:].plot(label="actual")
seasonal_forecast.plot(label="naive prediction (K=12)")
# Out:
# <Axes: xlabel='date'>

# %%
drift_model = NaiveDrift()
drift_model.fit(train)
drift_forecast = drift_model.predict(len(val))

combined_forecast = drift_forecast + seasonal_forecast - train.last_value()

train[-60:].plot(label="actual")
combined_forecast.plot(label="combined")
drift_forecast.plot(label="drift")
# Out:
# <Axes: xlabel='date'>

# %% [markdown]
# 9. Обчисліть помилку прогнозу на валідації наївною моделлю з mape. Далі для всіх моделей необхідно обчислювати помилку прогнозу на валідації.

# %%
from darts.metrics import mape

def eval_pred(forecast):
    print(f"Mean absolute percentage error for model: {mape(val, forecast):.2f}%.")

# %%
val.plot(label="actual")
combined_forecast.plot(label="combined")

eval_pred(combined_forecast)
# Out:
# Mean absolute percentage error for model: 42.18%.

# %% [markdown]
# 10. Натренуйте XBGModel з `darts` для передбачення наших даних. Можна додавати всі додаткові ознаки, які вважаєте за потрібне, наприклад, ознаки з дати. Зробіть висновок про якість моделі.

# %%
from darts.models import XGBModel
from darts.dataprocessing.transformers import Scaler
import numpy as np

def enrich_with_date_features(df):
  df["quarter"] = df['date'].dt.quarter
  df["year"] = df['date'].dt.year
  df["dayofyear"] = df['date'].dt.dayofyear
  df["sin_day"] = np.sin(df["dayofyear"])
  df["cos_day"] = np.cos(df["dayofyear"])
  return df

# Додавання ознак дати
train_transformed = enrich_with_date_features(train.pd_dataframe().reset_index())
val_transformed = enrich_with_date_features(val.pd_dataframe().reset_index())

# Масштабування даних
scaler = Scaler()
train_transformed = scaler.fit_transform(train)
test_transformed = scaler.transform(val)

# Побудова моделі XGBoost
model = XGBModel(
    lags=60,
    output_chunk_length=1,
    n_estimators=400,
    max_depth=5,
    learning_rate=0.1,
    subsample=0.8,
    colsample_bytree=0.8
)
model.fit(train_transformed)
pred = model.predict(6)
pred.values()

forecast = scaler.inverse_transform(model.predict(len(val)))
val.plot(label='Actual')
forecast.plot(label='Forecast', color='red')
plt.legend()
plt.show()
eval_pred(forecast)
# Out:
# Mean absolute percentage error for model: 41.18%.

# %% [markdown]
# 11. Натренуйте модель ExponentialSmoothing та зробіть висновок про її якість.

# %%
def plot_results(series, forecast):
  # Візуалізація результатів
  val.plot(label='Actual')
  forecast.plot(label='Forecast', color='red')
  plt.legend()
  plt.show()

def fit_and_plot(model, series, train, val):
  model.fit(train)
  forecast = model.predict(len(val))
  plot_results(series, forecast)
  eval_pred(forecast)

model = ExponentialSmoothing()
fit_and_plot(model, series, train, val)
# Out:
# Mean absolute percentage error for model: 39.01%.

# %% [markdown]
# 12. Натренуйте модель ARIMA, параметри оберіть самостійно.Зробіть висновок про її якість.

# %%
from darts.models import ARIMA

# Побудова та тренування моделі ARIMA
model = ARIMA(p=30, d=2, q=1) # try p=12
fit_and_plot(model, series, train, val)
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Mean absolute percentage error for model: 37.50%.

# %% [markdown]
# 13. Знайдіть оптимальні параметри моделі ARIMA з допомогою AutoARIMA моделі. Виконайте пошук параметрів, виведіть, які паарметри виявились оптимальними і обчисліть якість моделі. Чи поліпшилась якість порівняно з попереднім експериментом?

# %%
from darts.models import ExponentialSmoothing, AutoARIMA, Theta
model = AutoARIMA()
fit_and_plot(model, series, train, val)
# Out:
# Mean absolute percentage error for model: 37.90%.

# %% [markdown]
# 14. Натренуйте модель Prophet та зробіть висновок про її якість.

# %%
from darts.models import Prophet

model = Prophet()
model.fit(train)

forecast = model.predict(len(val))

fit_and_plot(model, series, train, val)
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4lc7etnw/lxqw4xrb.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4lc7etnw/mep9r333.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=60179', 'data', 'file=/tmp/tmp4lc7etnw/lxqw4xrb.json', 'init=/tmp/tmp4lc7etnw/mep9r333.json', 'output', 'file=/tmp/tmp4lc7etnw/prophet_model_d2oryjq/prophet_model-20241105171940.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:19:40 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:19:41 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4lc7etnw/j71kv3g2.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4lc7etnw/_6qrxl9a.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=30189', 'data', 'file=/tmp/tmp4lc7etnw/j71kv3g2.json', 'init=/tmp/tmp4lc7etnw/_6qrxl9a.json', 'output', 'file=/tmp/tmp4lc7etnw/prophet_modelzwnmo331/prophet_model-20241105171941.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:19:41 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:19:41 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Mean absolute percentage error for model: 23.80%.

# %% [markdown]
# 15. Натренуйте модель `RNNModel` та зробіть висновок про її якість.

# %%
from darts.models import RNNModel

from darts.utils.timeseries_generation import datetime_attribute_timeseries

# Масштабування даних
transformer = Scaler()
train_transformed = transformer.fit_transform(train)
val_transformed = transformer.transform(val)
series_transformed = transformer.transform(series)

display(series)

# Побудова та тренування моделі LSTM
model = RNNModel(
    model="LSTM",
    input_chunk_length=14,
    hidden_dim=20,
    dropout=0,
    batch_size=16,
    n_epochs=100,
    optimizer_kwargs={"lr": 1e-3},
    log_tensorboard=True,
    random_state=42,
    training_length=20,
    force_reset=True,
)
model.fit(
    train_transformed,
    val_series=val_transformed,
    verbose=True)

# Прогнозування
forecast = scaler.inverse_transform(model.predict(len(val)))

# Візуалізація результатів
val.plot(label='Actual')
forecast.plot(label='Forecast', color='red')
plt.legend()
plt.show()
# Out:
# <TimeSeries (DataArray) (date: 1826, component: 1, sample: 1)> Size: 15kB
# array([[[13.]],
#
#        [[11.]],
#
#        [[14.]],
#
#        ...,
#
#        [[15.]],
#
#        [[27.]],
#
#        [[23.]]])
# Coordinates:
#   * date       (date) datetime64[ns] 15kB 2013-01-01 2013-01-02 ... 2017-12-31
#   * component  (component) object 8B 'sales'
# Dimensions without coordinates: sample
# Attributes:
#     static_covariates:  None
#     hierarchy:          None
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: False, used: False
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name            | Type             | Params | Mode
# -------------------------------------------------------------
# 0 | criterion       | MSELoss          | 0      | train
# 1 | train_criterion | MSELoss          | 0      | train
# 2 | val_criterion   | MSELoss          | 0      | train
# 3 | train_metrics   | MetricCollection | 0      | train
# 4 | val_metrics     | MetricCollection | 0      | train
# 5 | rnn             | LSTM             | 1.8 K  | train
# 6 | V               | Linear           | 21     | train
# -------------------------------------------------------------
# 1.9 K     Trainable params
# 0         Non-trainable params
# 1.9 K     Total params
# 0.007     Total estimated model params size (MB)
# 7         Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=100` reached.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: False, used: False
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# Predicting: |          | 0/? [00:00<?, ?it/s]

# %%
eval_pred(forecast)
# Out:
# Mean absolute percentage error for model: 26.16%.

# %% [markdown]
# 16. Виконайте бектест для тої моделі, яка виявилась найкращою у вашому дослідженні на періоді 1 рік з передбаченнями на 1 місяць щоразу. Візуалізуйте як поводилась модель протягом бектесту, яка була точність?

# %%
from darts.models import Prophet

model = Prophet()
model.fit(train)

forecast = model.predict(len(val))

fit_and_plot(model, series, train, val)

hfc_params = {
    "series": series,
    "start": pd.Timestamp("2017-10-01"),  # can also be a float for the fraction of the series to start at
    "forecast_horizon": 3,
    "verbose": True,
}

historical_fcast = model.historical_forecasts(last_points_only=True, **hfc_params)

series[-250:].plot(label="data")
historical_fcast.plot(label="backtest 3-months ahead forecast")
print(f"MAPE = {mape(series, historical_fcast):.2f}%")
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4lc7etnw/ng6a1awr.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4lc7etnw/y84129ih.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=60910', 'data', 'file=/tmp/tmp4lc7etnw/ng6a1awr.json', 'init=/tmp/tmp4lc7etnw/y84129ih.json', 'output', 'file=/tmp/tmp4lc7etnw/prophet_modelxhl4eemt/prophet_model-20241105172810.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:28:10 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:28:10 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4lc7etnw/hsoldk1y.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4lc7etnw/o72lrgk0.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=90017', 'data', 'file=/tmp/tmp4lc7etnw/hsoldk1y.json', 'init=/tmp/tmp4lc7etnw/o72lrgk0.json', 'output', 'file=/tmp/tmp4lc7etnw/prophet_model4kumgij1/prophet_model-20241105172811.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:28:11 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:28:11 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Mean absolute percentage error for model: 23.80%.
#   0%|          | 0/90 [00:00<?, ?it/s]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4lc7etnw/ca4nmc9j.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4lc7etnw/u_up142c.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=24109', 'data', 'file=/tmp/tmp4lc7etnw/ca4nmc9j.json', 'init=/tmp/tmp4lc7etnw/u_up142c.json', 'output', 'file=/tmp/tmp4lc7etnw/prophet_model1c4dktg5/prophet_model-20241105172812.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:28:12 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:28:12 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#   1%|          | 1/90 [00:00<00:33,  2.62it/s]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4lc7etnw/8xuj6zy1.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4lc7etnw/eacux9h7.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=15877', 'data', 'file=/tmp/tmp4lc7etnw/8xuj6zy1.json', 'init=/tmp/tmp4lc7etnw/eacux9h7.json', 'output', 'file=/tmp/tmp4lc7etnw/prophet_model2pfy3a99/prophet_model-20241105172813.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:28:13 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:28:13 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#   2%|▏         | 2/90 [00:00<00:37,  2.32it/s]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4lc7etnw/ju4jbr6l.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4lc7etnw/g5i9spfa.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=57010', 'data', 'file=/tmp/tmp4lc7etnw/ju4jbr6l.json', 'init=/tmp/tmp4lc7etnw/g5i9spfa.json', 'output', 'file=/tmp/tmp4lc7etnw/prophet_model1d3an4lv/prophet_model-20241105172813.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:28:13 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:28:13 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#   3%|▎         | 3/90 [00:01<00:36,  2.41it/s]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4lc7etnw/ge7l6v0c.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4lc7etnw/b7cgr46m.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=4107', 'data', 'file=/tmp/tmp4lc7etnw/ge7l6v0c.json', 'init=/tmp/tmp4lc7etnw/b7cgr46m.json', 'output', 'file=/tmp/tmp4lc7etnw/prophet_model5vvmap95/prophet_model-20241105172813.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:28:13 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:28:14 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#   4%|▍         | 4/90 [00:01<00:35,  2.41it/s]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4lc7etnw/t_bnl04_.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4lc7etnw/q8jxv82b.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=76191', 'data', 'file=/tmp/tmp4lc7etnw/t_bnl04_.json', 'init=/tmp/tmp4lc7etnw/q8jxv82b.json', 'output', 'file=/tmp/tmp4lc7etnw/prophet_model6tbj7dz6/prophet_model-20241105172814.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:28:14 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:28:14 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#   6%|▌         | 5/90 [00:02<00:34,  2.50it/s]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4lc7etnw/tvpmhege.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4lc7etnw/3cq7_k2w.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=34697', 'data', 'file=/tmp/tmp4lc7etnw/tvpmhege.json', 'init=/tmp/tmp4lc7etnw/3cq7_k2w.json', 'output', 'file=/tmp/tmp4lc7etnw/prophet_modelmgu9r267/prophet_model-20241105172814.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:28:14 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:28:14 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#   7%|▋         | 6/90 [00:02<00:33,  2.48it/s]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4lc7etnw/2b7pb77m.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4lc7etnw/_uvc7ofz.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=2044', 'data', 'file=/tmp/tmp4lc7etnw/2b7pb77m.json', 'init=/tmp/tmp4lc7etnw/_uvc7ofz.json', 'output', 'file=/tmp/tmp4lc7etnw/prophet_mod
json', 'output', 'file=/tmp/tmp4lc7etnw/prophet_modeltwqlw9yh/prophet_model-20241105172902.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:29:02 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:29:02 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#  99%|█████████▉| 89/90 [00:50<00:00,  2.26it/s]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4lc7etnw/9r30sxee.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4lc7etnw/802kw388.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=25057', 'data', 'file=/tmp/tmp4lc7etnw/9r30sxee.json', 'init=/tmp/tmp4lc7etnw/802kw388.json', 'output', 'file=/tmp/tmp4lc7etnw/prophet_modelbilgc6v7/prophet_model-20241105172902.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:29:02 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:29:02 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 100%|██████████| 90/90 [00:50<00:00,  1.78it/s]
# MAPE = 23.09%

# %%
hfc_params = {
    "series": series,
    "start": pd.Timestamp("2017-10-01"),  # can also be a float for the fraction of the series to start at
    "forecast_horizon": 3,
    "verbose": True,
}

historical_fcast_all = model.historical_forecasts(last_points_only=False, stride=3, **hfc_params)

series[-150:].plot(label="data")
for idx, hfc in enumerate(historical_fcast_all):
    hfc.plot(label=f"forecast {idx}")

from darts import concatenate
historical_fcast_all = concatenate(historical_fcast_all, axis=0)
print(f"MAPE = {mape(series, historical_fcast_all):.2f}%")
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4lc7etnw/bngtqazs.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4lc7etnw/j2z3_tm1.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=29530', 'data', 'file=/tmp/tmp4lc7etnw/bngtqazs.json', 'init=/tmp/tmp4lc7etnw/j2z3_tm1.json', 'output', 'file=/tmp/tmp4lc7etnw/prophet_modelrxd78rmw/prophet_model-20241105172931.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:29:31 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:29:31 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#   3%|▎         | 1/30 [00:00<00:17,  1.63it/s]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4lc7etnw/7c3navao.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4lc7etnw/bqpjrk_0.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=51327', 'data', 'file=/tmp/tmp4lc7etnw/7c3navao.json', 'init=/tmp/tmp4lc7etnw/bqpjrk_0.json', 'output', 'file=/tmp/tmp4lc7etnw/prophet_model_pgjjtv7/prophet_model-20241105172932.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:29:32 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:29:32 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#   7%|▋         | 2/30 [00:01<00:16,  1.71it/s]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4lc7etnw/l5lo8jwz.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4lc7etnw/jlqhq8w1.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=63346', 'data', 'file=/tmp/tmp4lc7etnw/l5lo8jwz.json', 'init=/tmp/tmp4lc7etnw/jlqhq8w1.json', 'output', 'file=/tmp/tmp4lc7etnw/prophet_modell1syd7j9/prophet_model-20241105172932.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:29:32 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:29:33 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#  10%|█         | 3/30 [00:01<00:17,  1.51it/s]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4lc7etnw/bsp95zri.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4lc7etnw/eqngcb2e.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=34835', 'data', 'file=/tmp/tmp4lc7etnw/bsp95zri.json', 'init=/tmp/tmp4lc7etnw/eqngcb2e.json', 'output', 'file=/tmp/tmp4lc7etnw/prophet_modelaudv9foa/prophet_model-20241105172933.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:29:33 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:29:33 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#  13%|█▎        | 4/30 [00:03<00:23,  1.10it/s]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4lc7etnw/0razkjv_.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4lc7etnw/jtcg07ws.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=18233', 'data', 'file=/tmp/tmp4lc7etnw/0razkjv_.json', 'init=/tmp/tmp4lc7etnw/jtcg07ws.json', 'output', 'file=/tmp/tmp4lc7etnw/prophet_model05yjyj82/prophet_model-20241105172934.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:29:34 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:29:34 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#  17%|█▋        | 5/30 [00:03<00:19,  1.28it/s]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4lc7etnw/tflxvg0w.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4lc7etnw/fta1pl99.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=39810', 'data', 'file=/tmp/tmp4lc7etnw/tflxvg0w.json', 'init=/tmp/tmp4lc7etnw/fta1pl99.json', 'output', 'file=/tmp/tmp4lc7etnw/prophet_modelbw4763zf/prophet_model-20241105172935.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:29:35 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:29:35 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#  20%|██        | 6/30 [00:04<00:15,  1.52it/s]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4lc7etnw/46zd6ozh.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4lc7etnw/eu53jy2t.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=15619', 'data', 'file=/tmp/tmp4lc7etnw/46zd6ozh.json', 'init=/tmp/tmp4lc7etnw/eu53jy2t.json', 'output', 'file=/tmp/tmp4lc7etnw/prophet_modelurd_ne_q/prophet_model-20241105172935.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:29:35 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:29:35 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#  23%|██▎       | 7/30 [00:04<00:13,  1.75it/s]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4lc7etnw/raozkvmm.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4lc7etnw/t4na0274.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=80808', 'data', 'file=/tmp/tmp4lc7etnw/raozkvmm.json', 'init=/tmp/tmp4lc7etnw/t4na0274.json', 'output', 'file=/tmp/tmp4lc7etnw/prophet_modelufl599au/prophet_model-20241105172936.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:29:36 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:29:36 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#  27%|██▋       | 8/30 [00:05<00:11,  1.85it/s]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4lc7etnw/kzqw2ld8.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4lc7etnw/41gz9o7u.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=9297', 'data', 'file=/tmp/tmp4lc7etnw/kzqw2ld8.json', 'init=/tmp/tmp4lc7etnw/41gz9o7u.json', 'output', 'file=/tmp/tmp4lc7etnw/prophet_modelrr3prlbr/prophet_model-20241105172936.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:29:36 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:29:36 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#  30%|███       | 9/30 [00:05<00:10,  2.07it/s]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4lc7etnw/gh0muerg.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4lc7etnw/9otsoijv.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=55568', 'data', 'file=/tmp/tmp4lc7etnw/gh0muerg.json', 'init=/tmp/tmp4lc7etnw/9otsoijv.json', 'output', 'file=/tmp/tmp4lc7etnw/prophet_model0ibox8rc/prophet_model-20241105172936.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:29:36 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:29:36 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#  33%|███▎      | 10/30 [00:05<00:09,  2.12it/s]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4lc7etnw/dt00g7xv.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4lc7etnw/r0sn86a3.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=72739', 'data', 'file=/tmp/tmp4lc7etnw/dt00g7xv.json', 'init=/tmp/tmp4lc7etnw/r0sn86a3.json', 'output', 'file=/tmp/tmp4lc7etnw/prophet_modellvsuq_f1/prophet_model-20241105172937.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:29:37 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:29:37 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#  37%|███▋      | 11/30 [00:06<00:09,  2.09it/s]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4lc7etnw/ze15jfqj.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4lc7etnw/lvieoymr.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=89108', 'data', 'file=/tmp/tmp4lc7etnw/ze15jfqj.json', 'init=/tmp/tmp4lc7etnw/lvieoymr.json', 'output', 'file=/tmp/tmp4lc7etnw/prophet_modeldkv_kwq_/prophet_model-20241105172937.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:29:37 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:29:37 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#  40%|████      | 12/30 [00:06<00:08,  2.20it/s]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4lc7etnw/h1iilu7a.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4lc7etnw/03e9bncr.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=6802', 'data', 'file=/tmp/tmp4lc7etnw/h1iilu7a.json', 'init=/tmp/tmp4lc7etnw/03e9bncr.json', 'output', 'file=/tmp/tmp4lc7etnw/prophet_modelryes0wwt/prophet_model-20241105172938.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:29:38 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:29:38 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#  43%|████▎     | 13/30 [00:07<00:07,  2.27it/s]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4lc7etnw/qjhi1jdh.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4lc7etnw/b617siuh.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=58060', 'data', 'file=/tmp/tmp4lc7etnw/qjhi1jdh.json', 'init=/tmp/tmp4lc7etnw/b617siuh.json', 'output', 'file=/tmp/tmp4lc7etnw/prophet_modelaykrlnow/prophet_model-20241105172938.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:29:38 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:29:38 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#  47%|████▋     | 14/30 [00:07<00:06,  2.40it/s]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4lc7etnw/eyyyhxnd.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4lc7etnw/2f5a3gwp.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=65051', 'data', 'file=/tmp/tmp4lc7etnw/eyyyhxnd.json', 'init=/tmp/tmp4lc7etnw/2f5a3gwp.json', 'output', 'file=/tmp/tmp4lc7etnw/prophet_modeltzkryz5a/prophet_model-20241105172938.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:29:38 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:29:39 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#  50%|█████     | 15/30 [00:07<00:06,  2.45it/s]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4lc7etnw/a129u4oy.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4lc7etnw/qf0fmewj.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=54723', 'data', 'file=/tmp/tmp4lc7etnw/a129u4oy.json', 'init=/tmp/tmp4lc7etnw/qf0fmewj.json', 'output', 'file=/tmp/tmp4lc7etnw/prophet_model60kvu9zu/prophet_model-20241105172939.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:29:39 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:29:39 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#  53%|█████▎    | 16/30 [00:08<00:05,  2.55it/s]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4lc7etnw/pta0sg_v.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4lc7etnw/etv74pc1.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=51471', 'data', 'file=/tmp/tmp4lc7etnw/pta0sg_v.json', 'init=/tmp/tmp4lc7etnw/etv74pc1.json', 'output', 'file=/tmp/tmp4lc7etnw/prophet_model_3_7adic/prophet_model-20241105172939.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:29:39 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:29:39 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#  57%|█████▋    | 17/30 [00:08<00:05,  2.59it/s]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4lc7etnw/q7w4f9wf.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4lc7etnw/aezyqg49.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=13775', 'data', 'file=/tmp/tmp4lc7etnw/q7w4f9wf.json', 'init=/tmp/tmp4lc7etnw/aezyqg49.json', 'output', 'file=/tmp/tmp4lc7etnw/prophet_modeln7w_u2qy/prophet_model-20241105172940.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:29:40 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:29:40 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#  60%|██████    | 18/30 [00:09<00:04,  2.64it/s]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4lc7etnw/uhbspnag.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4lc7etnw/ky8s7dl3.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=99443', 'data', 'file=/tmp/tmp4lc7etnw/uhbspnag.json', 'init=/tmp/tmp4lc7etnw/ky8s7dl3.json', 'output', 'file=/tmp/tmp4lc7etnw/prophet_model5apvjori/prophet_model-20241105172940.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:29:40 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:29:40 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#  63%|██████▎   | 19/30 [00:09<00:04,  2.61it/s]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4lc7etnw/myyauy7m.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4lc7etnw/_8nk27be.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=11695', 'data', 'file=/tmp/tmp4lc7etnw/myyauy7m.json', 'init=/tmp/tmp4lc7etnw/_8nk27be.json', 'output', 'file=/tmp/tmp4lc7etnw/prophet_modelo8_2t396/prophet_model-20241105172940.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:29:40 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:29:40 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#  67%|██████▋   | 20/30 [00:09<00:03,  2.67it/s]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4lc7etnw/0djwm8_1.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4lc7etnw/bnezxkhd.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=53652', 'data', 'file=/tmp/tmp4lc7etnw/0djwm8_1.json', 'init=/tmp/tmp4lc7etnw/bnezxkhd.json', 'output', 'file=/tmp/tmp4lc7etnw/prophet_model15kag0i1/prophet_model-20241105172941.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:29:41 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:29:41 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#  70%|███████   | 21/30 [00:10<00:03,  2.68it/s]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4lc7etnw/noq2j413.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4lc7etnw/w2xybi30.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=9510', 'data', 'file=/tmp/tmp4lc7etnw/noq2j413.json', 'init=/tmp/tmp4lc7etnw/w2xybi30.json', 'output', 'file=/tmp/tmp4lc7etnw/prophet_modellhy2itt4/prophet_model-20241105172941.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:29:41 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:29:41 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#  73%|███████▎  | 22/30 [00:10<00:02,  2.71it/s]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4lc7etnw/wbb2vq64.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4lc7etnw/p4383920.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=58460', 'data', 'file=/tmp/tmp4lc7etnw/wbb2vq64.json', 'init=/tmp/tmp4lc7etnw/p4383920.json', 'output', 'file=/tmp/tmp4lc7etnw/prophet_modelzf2btfhg/prophet_model-20241105172941.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:29:41 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:29:42 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#  77%|███████▋  | 23/30 [00:10<00:02,  2.58it/s]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4lc7etnw/wbhjgbcy.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4lc7etnw/odvc67tf.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=19461', 'data', 'file=/tmp/tmp4lc7etnw/wbhjgbcy.json', 'init=/tmp/tmp4lc7etnw/odvc67tf.json', 'output', 'file=/tmp/tmp4lc7etnw/prophet_modelocgu7dtw/prophet_model-20241105172942.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:29:42 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:29:42 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#  80%|████████  | 24/30 [00:11<00:02,  2.48it/s]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4lc7etnw/eph8227h.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4lc7etnw/qmrb1pcg.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=46392', 'data', 'file=/tmp/tmp4lc7etnw/eph8227h.json', 'init=/tmp/tmp4lc7etnw/qmrb1pcg.json', 'output', 'file=/tmp/tmp4lc7etnw/prophet_modelaatgtpps/prophet_model-20241105172942.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:29:42 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:29:42 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#  83%|████████▎ | 25/30 [00:11<00:01,  2.56it/s]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4lc7etnw/hm_6w2w2.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4lc7etnw/cxa4ws8h.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=60035', 'data', 'file=/tmp/tmp4lc7etnw/hm_6w2w2.json', 'init=/tmp/tmp4lc7etnw/cxa4ws8h.json', 'output', 'file=/tmp/tmp4lc7etnw/prophet_modelw7m5q2dw/prophet_model-20241105172943.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:29:43 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:29:43 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#  87%|████████▋ | 26/30 [00:12<00:01,  2.51it/s]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4lc7etnw/krdxnbzz.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4lc7etnw/iwgi_bgs.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=36770', 'data', 'file=/tmp/tmp4lc7etnw/krdxnbzz.json', 'init=/tmp/tmp4lc7etnw/iwgi_bgs.json', 'output', 'file=/tmp/tmp4lc7etnw/prophet_modelp9caadgn/prophet_model-20241105172943.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:29:43 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:29:43 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#  90%|█████████ | 27/30 [00:12<00:01,  2.58it/s]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4lc7etnw/cneis21g.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4lc7etnw/jzps1gtp.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=6514', 'data', 'file=/tmp/tmp4lc7etnw/cneis21g.json', 'init=/tmp/tmp4lc7etnw/jzps1gtp.json', 'output', 'file=/tmp/tmp4lc7etnw/prophet_modelalqiy07e/prophet_model-20241105172943.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:29:43 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:29:44 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#  93%|█████████▎| 28/30 [00:12<00:00,  2.45it/s]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4lc7etnw/kc_spmua.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4lc7etnw/w01r7lm1.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=60820', 'data', 'file=/tmp/tmp4lc7etnw/kc_spmua.json', 'init=/tmp/tmp4lc7etnw/w01r7lm1.json', 'output', 'file=/tmp/tmp4lc7etnw/prophet_modelgtoknjhx/prophet_model-20241105172944.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:29:44 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:29:44 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#  97%|█████████▋| 29/30 [00:13<00:00,  2.48it/s]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4lc7etnw/l6989nvn.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4lc7etnw/m0gbr14i.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=8198', 'data', 'file=/tmp/tmp4lc7etnw/l6989nvn.json', 'init=/tmp/tmp4lc7etnw/m0gbr14i.json', 'output', 'file=/tmp/tmp4lc7etnw/prophet_modelpvmz5kry/prophet_model-20241105172944.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:29:44 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:29:44 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 100%|██████████| 30/30 [00:13<00:00,  2.17it/s]
# MAPE = 23.54%

# %% [markdown]
# Всю варіантивність не вгадали, але виглядає непогано!

# %% [markdown]
# 17. На цьому етапі ви зрозуміли, як моделювати продажі одного айтему з 1 магазину. Як би ви підійшли до задачі прогнозування продажів в наступному місяці для кожного з 50 айтемів в кожному з 10 магазинів? Опишіть загальний підхід
# - яку модель ви б використали
# - скільки моделей ви б тренували
# - обгрунтуйте свій вибір.

# %% [markdown]
# 1) для кожного магазину та для кожної позиції можна використати окрему Prophet модель, що підвищить точність прогнозу.
# 2) Якщо вибирати одну модель то це XGBboost/LGBM
